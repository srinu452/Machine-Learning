# %% [markdown]
# <div class="alert alert-info">
# <h1><center><font color=darkblue>Regression <font></center></h1>

# %% [markdown]
#         Basically ,Regression is a statistical approach to find the correlations between variables(dependent and independent).
#
#         Regression algorithms give you a continous output.That means if you asked to build a model that predicts the future outcome where the output will be continous.Then you must choose one of the Regression algorithms to build your model.

# %% [markdown]
#         A regression problem is when the output variable is a real or continuous value, such as “salary” or “weight”. Many different models can be used, the simplest is the linear regression. It tries to fit data with the best hyper-plane which goes through the points.

# %% [markdown]
# # <font color='darkred'>Types of Regression<font>

# %% [markdown]
# # <font color=' orange'>1.Simple Linear Regression<font>
# # <font color='orange'>2.Multiple Linear Regression<font>
# # <font color=' orange'>3.Polynomial Regression<font>
# # <font color=' orange'>4.Decision Tree Regressor<font>
# # <font color=' orange'>5.Random Forest Regressor<font>

# %% [markdown]
# # What is Linear Regression?

# %% [markdown]
#                     Linear regression algorithm shows a linear relationship between a dependent (y) and one or more independent (y) variables, hence called as linear regression. Since linear regression shows the linear relationship, which means it finds how the value of the dependent variable is changing according to the value of the independent variable.

# %% [markdown]
# # Types of Linear Regression

# %% [markdown]
#         Linear regression can be further divided into two types of the algorithm:

# %% [markdown]
# ## Simple Linear Regression:
#         If a single independent variable is used to predict the value of a numerical dependent variable,then such a Linear Regression algorithm is called Simple Linear Regression.
#
# ## Multiple Linear Regression:
#         If more than one independent variable is used to predict  the value of a numerical dependent variable,then such a Linear Regression algorithm is called Multiple Linear Regression.

# %% [markdown]
# <div class="alert alert-info">
# <h1><center><font color=darkblue>Simple Linear Regression <font></center></h1>

# %% [markdown]
# # <font color='green'>What is Simple Linear Regression?<font>

# %% [markdown]
#         A simple Linear Regression model only has two explanatory variable.Think of a two-dimentional space where the horizontal axis represents the indpendent variable x,and the vertical axis represents the dependent variable y.

# %% [markdown]
#         Simple Linear regression is a type of Regression algorithm, that models the relationship between a dependent variable and a single independent variable.

# %% [markdown]
#         The relationship shown by a simple linear regression model is linear or Sloped Straight line, hence its called Simple Linear Regression.

# %% [markdown]
# # <font color='green'>Assumptions of Simple Linear Regression<font>

# %% [markdown]
# # Linear :
#         It assumes that the relation between the data points is linear i.e the plot of the data points shows is linear.
# # Independence :
#         There must be no relationship among the different values of the independent variables i.e the value is unique.
# # Normality :
#         Data points follow a normal distribution i.e if we plot the histogram of the data,we should be able to draw a skewed line. that means bell shape curve we should see

# %%
from PIL import Image
Image.open('s15.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1132x639>

# %% [markdown]
#         The relationship between the independent and dependent variables must be a linear ,then only we should perform this model.

# %%
Image.open('s16.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=842x599>

# %% [markdown]
#         Y= denotes the Dependent variable
#         X= denoted the Independent Variable
#         b₀ = It is a constant term. (intercept)
#         b₁ = It is a co-efficient for the Independent variable (slope)

# %% [markdown]
# # <font color='green'>How to find the best fit line?<font>

# %% [markdown]
#         In this regression model,we are trying to minimize the errors in prediction by finding the "Line of Best Fit"-the regression line from the errors would be minimal.We are trying to minimize the length between the observed value(Yi) and the predicted value from our model(Yp).

# %% [markdown]
# # <font color='green'>Cost function or Loss Function or Error function<font>

# %% [markdown]
#         The difference between the original values and predicted values i.e. is called cost function.

# %%
Image.open('s17.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1125x331>

# %% [markdown]
# # <font color='green'>Let's Code <font>

# %% [markdown]
# # 1.Data Preprocessing
# # 2.Fitting the model to the Training Data
# # 3.Predicting the results
# # 4.Visualization

# %% [markdown]
# # <font color='green'>How to improve the model<font>

# %%
Image.open('s18.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1125x666>

# %% [markdown]
#         1.Normalize the Data : --> improve th accuracy by converting into feature scaling tools like StandardScaler and Normalization
#
#         2.Remove Outliers :--> Outliers which have vast distance from Similarity values.
#
#         3.Check Collinearity : --> check the relation between independent variables ,make sure to avoid highest collinearity variables which reduces the accuracy.

# %% [markdown]
# <div class="alert alert-info">
# <h1><center><font color=violite>Implementation of Simple Linear Regression <font></center></h1>

# %%
# Importing the Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as ps
import seaborn as sns

# %%
# Load the Dataset
dataset=pd.read_csv('Salary_Data.csv')

# %%
dataset.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              4.0   51092

# %%
dataset.tail()
# Out:
#     YearsExperience  Salary
# 27              9.0  105582
# 28              9.5  116969
# 29              9.6  112635
# 30             10.3  122391
# 31             10.5  121872

# %%
# data preprocessing

# %%
#checking for missing data in the dataset
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
# checking for duplicated data
dataset.duplicated().sum()
# Out:
# 0

# %%
# checking for outliers 
sns.boxplot(data=dataset,x='Salary')
plt.show()

# %%
# Splitting the data into training and testing

# %%
X=dataset.iloc[:,:1].values
Y=dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
# Performing the required algorithm

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
x_pred=regressor.predict(x_train)

# %%
y_test # original
# Out:
# array([ 57189,  91738,  64445,  37731,  61111,  56957, 116969],
#       dtype=int64)

# %%
y_pred #predicted
# Out:
# array([ 59818.90355786,  89190.45330647,  55081.55682421,  38974.57792981,
#         67398.6583317 ,  62661.31159805, 114772.12566817])

# %%
#visiualization

# %%
plt.title("Training Pred")
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,x_pred,color='blue')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
plt.title("Testing pred")
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_pred,color='blue')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
