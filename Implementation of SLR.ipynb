# %% [markdown]
# # Regression

# %% [markdown]
# ## What is Regression?

# %% [markdown]
#         Basically,Regression is a statistical approach to find the correlations between varaibles(dependent and independent).

# %% [markdown]
#         A regression problem is when the output variable is a real or continuous value,such as 'salary' or 'weight'.Many different models can be used ,the simplest is the linear regression.It tries to fit data with the best hyper-plane which goes through the points.

# %% [markdown]
#         Regression algorithm give you a continuous output.That means if your are asked to build a model that predicts the future outcome where the output will be continuous .Then you must choose one of the Regression algorithms to build your model.

# %% [markdown]
# #####    Thing Under the Regression:

# %% [markdown]
#     * Linear Regression
#     * Multiple Linear Regression
#     * Backward Elimination
#     * Polynomial Regression
#     * Decision Tree Regressor
#     * Random Forest Regressor

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## What is Linear Regression?

# %% [markdown]
#         Linear Regression algorithm shows a linear relationship between a depedent(y) and one or more independent(y) variables,hence called as linear regression.Since linear regression shows the linear relationship,which means it finds how the value of the dependent variable is changing according to the value of the independent variable.

# %% [markdown]
#         A simple linear regression model only has two explanatory variables-one dependent and one independent variable.Think of a two -dimentional space where the horizontal axis represents the independent varaible x,and the vertical axis represents the dependent variable y.

# %% [markdown]
# ## Types of Linear Regression

# %% [markdown]
#     Linear regression can be further divided into two types of the algorithm:

# %% [markdown]
# ### * Simple Linear Regression:
#         If a single independent variable is used to predict the value of a numerical dependent(Target) variable,then such a Linear Regression algorithm is called Simple Linear regression.
# ### * Multiple Linear Regression:
#         If more then one independent variable is used to predict the value of numerical dependent variable,then such a Linear Regression algorithm is called Multiple Linear Regression.

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
#         Simple Linear regression is a type of Regression algorithm,that models the relationship between a dependent variable and a single independent variable.
#         The relationship shown by a simple linear regression model is linear or Sloped Stright line,hence its called Simple Linear Regression.
#         The Simple Linear Regression Model can be represented using the below equation.

# %% [markdown]
# ### Equation -> Y= b₀+b₁*X

# %% [markdown]
#     Y=denotes the Dependent Variable
#     X=denoted the Independent Variable
#     b₀=It is a constant term.
#     b₁=It is a co-efficient for the Independent variable.

# %% [markdown]
# ## Simple Linear Regression:

# %%
from PIL import Image
Image.open('lng.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=811x336>

# %% [markdown]
# ## Assumptions of Simple Linear Regression
#
# ### 1. Linearity :
#         It assumes that the relation between the data points is linear i.e the plot of the data points shows linear
# ### 2.Independence :
#         There must be no relationship among the different values of the independent varaible i.e., the value is unique.
# ### Normality :
#         Data points follow a normal ditribution i.e if we plot the histogram of the data,we should be able to draw a skewed line.i.e means it should be form one bell-curved shape.

# %% [markdown]
# ## How to find the best fit line?
#         In this regression model,we are trying to minimize the errors in prediction by finding the 'line of best fit'-the regression line from the errors would be minimal.We are trying to minimize the length between the observed value(Yi) and the predicted value from our model(Yp).
#
# ## Cost function or Lost Function or  Error function:
#         If we wana get good model or best fit line ,it will depends on the cost function.
#         Cost function means the error between the actual value and predicted value.If the error is low our model is good else not good.
#
# ### Formula :
#     Yi->Actual Value
#     Yp->Predicted value
#
# ### min{sum(Yi-Yp)2}

# %% [markdown]
# #### Problem Statement Example for the Simple Linear Regression:
# #### Assume we are taking a dataset that has two variables

# %% [markdown]
# ##### * Salary-(Dependent Variable)
# ##### * Experience-(Independent Variable)
#
# * We need to Find the correlation between the two variables.
# * Need to find out the best fit line for the dataset.
# * How the Dependent variable is changing by changing the independent variable?

# %% [markdown]
# ## How to improve the model.
#
# ####        1. Normalize the data --> feature scaling
# ####        2. Remove Outliers---> value outside the normal distribution
# ####        3. check collinearity.---> relationship between variables.

# %% [markdown]
# ## Step by Step Procedure for Simple Linear regression Model program

# %% [markdown]
# ### Steps of Simple Linear Regression Model:
#
# ##### 1. Data Preprocessing
# ##### 2. Fitting the Simple Linear Regression to the Training Set
# ##### 3. Prediction of test set result
# ##### 4. Visualizing the Training set results
# ##### 5. Visualizing the Test set results.

# %% [markdown]
# ## 1.Data Preprocessing:
#         Data Preprocessing is the main proportion of the program.We need Import the libraries and Dataset ,to train and test the data's.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px

# %%
dataset=pd.read_csv('Salary_Data.csv')
dataset.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              4.0   51092

# %%
dataset.tail()
# Out:
#     YearsExperience  Salary
# 27              9.0  105582
# 28              9.5  116969
# 29              9.6  112635
# 30             10.3  122391
# 31             10.5  121872

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  32 non-null     float64
#  1   Salary           32 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 644.0 bytes

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
#         So we don't have any null values or any unwanted data to disturb the Accuracy of prediction while performing machine Learning Algorithm.

# %%
X=dataset.iloc[:,:-1].values
Y=dataset.iloc[:,1].values

# %%
Image.open('iloc.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1139x585>

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 4. ],
#        [ 5. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
Y
# Out:
# array([ 39343,  46205,  37731,  43525,  51092,  55000,  39891,  56642,
#         60150,  54445,  64445,  57189,  63218,  55794,  56957,  57081,
#         61111,  67938,  66029,  83088,  81363,  93940,  91738,  98273,
#        101302, 113812, 109431, 105582, 116969, 112635, 122391, 121872],
#       dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# this step is used to split the dataset into train and test data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
X_train
# Out:
# array([[ 5.9],
#        [ 4. ],
#        [ 7.9],
#        [ 5. ],
#        [ 4.9],
#        [ 3. ],
#        [10.3],
#        [ 8.2],
#        [ 7.1],
#        [ 1.3],
#        [10.5],
#        [ 2.2],
#        [ 4. ],
#        [ 5.1],
#        [ 9.6],
#        [ 5.3],
#        [ 3.2],
#        [ 2.9],
#        [ 9. ],
#        [ 2. ],
#        [ 1.1],
#        [ 6. ],
#        [ 4.1],
#        [ 3.9]])

# %%
Y_train
# Out:
# array([ 81363,  55794, 101302,  55000,  67938,  60150, 122391, 113812,
#         98273,  46205, 121872,  39891,  51092,  66029, 112635,  83088,
#         54445,  56642, 105582,  43525,  39343,  93940,  57081,  63218],
#       dtype=int64)

# %%
X_test
# Out:
# array([[3.7],
#        [6.8],
#        [3.2],
#        [1.5],
#        [4.5],
#        [4. ],
#        [9.5],
#        [8.7]])

# %%
Y_test
# Out:
# array([ 57189,  91738,  64445,  37731,  61111,  56957, 116969, 109431],
#       dtype=int64)

# %% [markdown]
# ## 2.Fitting the Simple Linear Regression to the Training Set:
#         Now,we will import the 'LinearRegression' class of the 'linear_model' library from the scikit learn.After importing the class ,we are going to create an object of the class named as a 'regressor'.

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
#     Here we gave the data to learn the module from this train_dataset to know to predict while testing the dataset.

# %% [markdown]
# ##### fit():
#         This method to fit our Simple Linear Regression object to the training set

# %% [markdown]
# ## 3.Predicting the test set results:

# %% [markdown]
#         So,now our model is already to predict the output for the new observations.In this step,we will provide the test dataset(new observations) to the model to check wheather it can predict the correct output or not.
#
#         We will create a prediction vector 'y_pred' and 'x_pred',which will contain predictions of test dataset,and prediction of training set respectively.

# %%
# predicting the Test set results
Y_pred=regressor.predict(X_test)
X_pred=regressor.predict(X_train)

# %% [markdown]
#  #####       y_pred & x_pred:It will contain predictions of test dataset.

# %%
X_test
# Out:
# array([[3.7],
#        [6.8],
#        [3.2],
#        [1.5],
#        [4.5],
#        [4. ],
#        [9.5],
#        [8.7]])

# %%
Y_pred
# Out:
# array([ 59792.57198406,  89032.00817467,  55076.5338888 ,  39042.00436491,
#         67338.23293647,  62622.19484121, 114498.61388908, 106952.95293666])

# %%
X_train
# Out:
# array([[ 5.9],
#        [ 4. ],
#        [ 7.9],
#        [ 5. ],
#        [ 4.9],
#        [ 3. ],
#        [10.3],
#        [ 8.2],
#        [ 7.1],
#        [ 1.3],
#        [10.5],
#        [ 2.2],
#        [ 4. ],
#        [ 5.1],
#        [ 9.6],
#        [ 5.3],
#        [ 3.2],
#        [ 2.9],
#        [ 9. ],
#        [ 2. ],
#        [ 1.1],
#        [ 6. ],
#        [ 4.1],
#        [ 3.9]])

# %%
X_pred
# Out:
# array([ 80543.1396032 ,  62622.19484121,  99407.29198424,  72054.27103173,
#         71111.06341268,  53190.11865069, 122044.27484149, 102236.9148414 ,
#         91861.63103183,  37155.58912681, 123930.6900796 ,  45644.45769828,
#         62622.19484121,  72997.47865079, 115441.82150813,  74883.89388889,
#         55076.5338888 ,  52246.91103164, 109782.57579382,  43758.04246017,
#         35269.17388871,  81486.34722225,  63565.40246027,  61678.98722216])

# %% [markdown]
# ## 4.Visualizing the Training set results:

# %% [markdown]
#         We will visualize the training set result.To do so,we will use the scatter() function of the pyplot library,which we have already imported in the pre-processing step.

# %%
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,X_pred,color='blue')
plt.title('Salary vs Experience(Training set)')
plt.xlabel('Years of Experience')
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ### Visualizing the Test Set results:
#         We have visualized the performance of our model on the training set. Now, we will do the same for the Test set. The complete code will remain the same as the above code, except in this, we will use x_test, and y_test instead of x_train and y_train.

# %%
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_test,Y_pred,color='blue')
plt.title('Salary vs Experience(Training set)')
plt.xlabel('Years of Experience')
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# # Simple Linear Regression Templete

# %% [markdown]
# ### //Complete Program of Simple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset=pd.read_csv('Salary_Data.csv')
X=dataset.iloc[:,:-1].values
Y=dataset.iloc[:,1].values

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.50,random_state=0)

from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)

Y_pred=regressor.predict(X_test)
X_pred=regressor.predict(X_train)

plt.scatter(X_train,Y_train,color='yellow')
plt.plot(X_train,Y_pred,color='blue')
plt.title('Salary&Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
plt.scatter(X_test,Y_test,color='yellow')
plt.plot(X_test,X_pred,color='blue')
plt.title('Salary&Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
X_test
# Out:
# array([[ 3.7],
#        [ 6.8],
#        [ 3.2],
#        [ 1.5],
#        [ 4.5],
#        [ 4. ],
#        [ 9.5],
#        [ 8.7],
#        [ 5.9],
#        [ 4. ],
#        [ 7.9],
#        [ 5. ],
#        [ 4.9],
#        [ 3. ],
#        [10.3],
#        [ 8.2]])

# %%
Y_pred
# Out:
# array([ 60462.2018778 ,  88801.64314085,  55891.32425472,  40350.34033628,
#         67775.60607471,  63204.72845164, 113484.38230544, 106170.97810853,
#         80574.06341932,  63204.72845164,  98857.57391161,  72346.48369779,
#         71432.30817317,  54062.9732055 , 120797.78650236, 101600.10048545])

# %%
Y_test
# Out:
# array([ 57189,  91738,  64445,  37731,  61111,  56957, 116969, 109431,
#         81363,  55794, 101302,  55000,  67938,  60150, 122391, 113812],
#       dtype=int64)

# %% [markdown]
#         Y_test= Training Data Set.
#         Y_Pred= Prediction Data Set.
#         In Above Picture, we can see the Test set and predicted set Data of Salary.
#         Hence the Output of the predicted data is 85% similar to training set.

# %%
a=input()

b=input()

c=a+b
print(c)
