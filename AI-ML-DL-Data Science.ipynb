# %% [markdown]
# # <font color='Dark Blue'> AI-Ml-DL<font>

# %% [markdown]
# # <font color='Dark green'> Artificial Intelligence<font>

# %% [markdown]
#         Making Machine to think and analyze and Make a decision.
#         It will create smart computers which thinks and actions do like human.
#         Example :
#         1.Self Driving Cars
#         2.Robotics.

# %% [markdown]
# # <font color='Dark green'> Machine Learning<font>

# %% [markdown]
#         Machine Learning is a subset of Artificial Intelligence that uses statistical learning algorithms to build systems that have the ability to automatically learn and improve from experiences without being explicitly programmed which means normal algorithms which are directly knows which output we have predict.

# %% [markdown]
#         Machine Learning is the study of computer algorithms that improve automatically through experiences.

# %%
from PIL import Image
Image.open('s6.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1116x489>

# %% [markdown]
#         Examples:
#
#         1.Recommendation System.
#         2.Amazon Alexa.

# %% [markdown]
# # <font color='dark pink'>Deep Learning <font>

# %% [markdown]
#     1.Brain Inspired Machine Learning Models.
#
#     2.Subset of ML which uses deep Neural Networks as models and automatically builds a heirarchy of data represents.

# %% [markdown]
# ## Moslty used Neural Networks are
#
# #### 1.Artificial Neural Networks :
#         This model used whenever our input data should be like vectors.
# #### 2.Convolutional Neural Networks:
#         This model used whenever our input data should be like vedios ,audios, images.
# #### 3.Recurrent Neural Networks.
#         This model used whenever our input data should be like Time series problems and sequence of data

# %% [markdown]
#     Examples :
#         1.Facial Recognition System
#         2.Image Captioning

# %% [markdown]
# # <font color='Darkblue'>Data Science<font>

# %% [markdown]
# ## What is Data Science?

# %% [markdown]
#     Data science is a concept in computer science which is used to study and analyze and  predict the data.
#
#     It will works on statistical analysis and data analysis for analysing the data.
#
#     Data science is a combination of "AI-ML-DL-Data Science" and "statistical analysis"and "Data Analysis".

# %% [markdown]
# ## <font color='blue'>Mostly used Data Analytics Tools:<font>
# ###    1.PowerBi
# ###    2.Tableau
# ###    3.Excel
